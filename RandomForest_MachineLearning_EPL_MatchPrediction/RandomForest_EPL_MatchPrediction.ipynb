# %% [markdown]
# # ENGLISH PREMIER LEAGUE MATCH PREDICTION USING RANDOM FOREST

# %% [markdown]
# ### DATA SCRAPING

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)
data
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(data.text)

standings_table = soup.select('table.stats_table')[0]

links = standings_table.find_all('a')

links = [l.get("href") for l in links]

links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
matches.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result  GF  GA        Opponent   xG  xGA  Poss  Attendance          Captain  \
# 0      L   1   3       Liverpool  NaN  NaN    57         NaN       Rúben Dias
# 1      W   2   0        West Ham  2.2  0.5    75     62443.0   İlkay Gündoğan
# 2      W   4   0     Bournemouth  1.7  0.1    67     53453.0   İlkay Gündoğan
# 3      D   3   3   Newcastle Utd  2.1  1.8    69     52258.0   İlkay Gündoğan
# 4      W   4   2  Crystal Palace  2.2  0.1    74     53112.0  Kevin De Bruyne
#
#   Formation         Referee  Match Report Notes
# 0     4-3-3    Craig Pawson  Match Report   NaN
# 1     4-3-3  Michael Oliver  Match Report   NaN
# 2   4-2-3-1     David Coote  Match Report   NaN
# 3     4-3-3  Jarred Gillett  Match Report   NaN
# 4   4-2-3-1  Darren England  Match Report   NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head()
# Out:
#   For Manchester City                                                     \
#                  Date   Time              Comp                Round  Day
# 0          2022-07-30  17:00  Community Shield  FA Community Shield  Sat
# 1          2022-08-07  16:30    Premier League          Matchweek 1  Sun
# 2          2022-08-13  15:00    Premier League          Matchweek 2  Sat
# 3          2022-08-21  16:30    Premier League          Matchweek 3  Sun
# 4          2022-08-27  15:00    Premier League          Matchweek 4  Sat
#
#                                          ... Standard               Expected  \
#      Venue Result GF GA        Opponent  ...     Dist   FK PK PKatt       xG
# 0  Neutral      L  1  3       Liverpool  ...      NaN  NaN  0     0      NaN
# 1     Away      W  2  0        West Ham  ...     18.7  1.0  1     1      2.2
# 2     Home      W  4  0     Bournemouth  ...     17.5  0.0  0     0      1.7
# 3     Away      D  3  3   Newcastle Utd  ...     16.2  1.0  0     0      2.1
# 4     Home      W  4  2  Crystal Palace  ...     14.1  0.0  0     0      2.2
#
#                             Unnamed: 25_level_0
#   npxG npxG/Sh G-xG np:G-xG        Match Report
# 0  NaN     NaN  NaN     NaN        Match Report
# 1  1.4    0.11 -0.2    -0.4        Match Report
# 2  1.7    0.09  1.3     1.3        Match Report
# 3  2.1    0.10  0.9     0.9        Match Report
# 4  2.2    0.13  1.8     1.8        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()
shooting.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result  GF  GA        Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      L   1   3       Liverpool  ...   NaN  NaN   0      0  NaN   NaN
# 1      W   2   0        West Ham  ...  18.7  1.0   1      1  2.2   1.4
# 2      W   4   0     Bournemouth  ...  17.5  0.0   0      0  1.7   1.7
# 3      D   3   3   Newcastle Utd  ...  16.2  1.0   0      0  2.1   2.1
# 4      W   4   2  Crystal Palace  ...  14.1  0.0   0      0  2.2   2.2
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1     0.11  -0.2     -0.4  Match Report
# 2     0.09   1.3      1.3  Match Report
# 3     0.10   0.9      0.9  Match Report
# 4     0.13   1.8      1.8  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result  GF  GA        Opponent  ...  Formation         Referee  \
# 0      L   1   3       Liverpool  ...      4-3-3    Craig Pawson
# 1      W   2   0        West Ham  ...      4-3-3  Michael Oliver
# 2      W   4   0     Bournemouth  ...    4-2-3-1     David Coote
# 3      D   3   3   Newcastle Utd  ...      4-3-3  Jarred Gillett
# 4      W   4   2  Crystal Palace  ...    4-2-3-1  Darren England
#
#    Match Report  Notes  Sh SoT  Dist   FK PK  PKatt
# 0  Match Report    NaN  14   8   NaN  NaN  0      0
# 1  Match Report    NaN  13   1  18.7  1.0  1      1
# 2  Match Report    NaN  19   7  17.5  0.0  0      0
# 3  Match Report    NaN  21  10  16.2  1.0  0      0
# 4  Match Report    NaN  18   5  14.1  0.0  0      0
#
# [5 rows x 25 columns]

# %%
years = list(range(2023, 2018, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.head()

# %%
match_df.to_csv("matches.csv")

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.shape
# Out:
# (1520, 27)

# %% [markdown]
# ### DATA CLEANING

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %% [markdown]
# #### CREATE PREDICTORS

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["team_code"] = matches["team"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(':.+', '', regex=True).astype('int')
matches["day_code"] = matches['date'].dt.dayofweek
# matches["target"] = matches['result'].astype('category').cat.codes
matches["target"] = (matches['result'] == 'W').astype('int')
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...   pk  pkatt  season             team venue_code  \
# 1         West Ham  ...  1.0    1.0    2023  Manchester City          0
# 2      Bournemouth  ...  0.0    0.0    2023  Manchester City          1
# 3    Newcastle Utd  ...  0.0    0.0    2023  Manchester City          0
# 4   Crystal Palace  ...  0.0    0.0    2023  Manchester City          1
# 5  Nott'ham Forest  ...  0.0    0.0    2023  Manchester City          1
#
#   opp_code team_code hour  day_code  target
# 1       21        13   16         6       1
# 2        2        13   15         5       1
# 3       15        13   16         6       0
# 4        7        13   15         5       1
# 5       17        13   19         2       1
#
# [5 rows x 33 columns]

# %% [markdown]
# ### MODEL TRAINING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']
test = matches[matches["date"] >= '2023-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc =accuracy_score(test['target'], preds)
acc
# Out:
# 0.5949074074074074

# %%
combined = pd.DataFrame({'Actual':test['target'], 'Prediction':preds})

# %%
pd.crosstab(index=combined['Actual'], columns=combined['Prediction'])
# Out:
# Prediction    0   1
# Actual
# 0           204  62
# 1           113  53

# %%
precision = precision_score(combined['Actual'], combined['Prediction'])

# %% [markdown]
# ### MODEL TUNING

# %%
grouped_matches = matches.groupby('team')
grouped_matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...          ...  ...   ...    ...  ..  ..
# 0  2021-08-14  17:30  Premier League  Matchweek 1  Sat  Home      L   0   3
# 1  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Away      L   0   5
# 3  2021-08-28  15:00  Premier League  Matchweek 3  Sat  Home      L   1   2
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      L   0   1
# 5  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      L   1   3
#
#            opponent  ...   pk  pkatt  season             team venue_code  \
# 1          West Ham  ...  1.0    1.0    2023  Manchester City          0
# 2       Bournemouth  ...  0.0    0.0    2023  Manchester City          1
# 3     Newcastle Utd  ...  0.0    0.0    2023  Manchester City          0
# 4    Crystal Palace  ...  0.0    0.0    2023  Manchester City          1
# 5   Nott'ham Forest  ...  0.0    0.0    2023  Manchester City          1
# ..              ...  ...  ...    ...     ...              ...        ...
# 0         Liverpool  ...  0.0    0.0    2022     Norwich City          1
# 1   Manchester City  ...  0.0    0.0    2022     Norwich City          0
# 3    Leicester City  ...  1.0    1.0    2022     Norwich City          1
# 4           Arsenal  ...  0.0    0.0    2022     Norwich City          0
# 5           Watford  ...  0.0    0.0    2022     Norwich City          1
#
#    opp_code team_code hour  day_code  target
# 1        21        13   16         6       1
# 2         2        13   15         5       1
# 3        15        13   16         6       0
# 4         7        13   15         5       1
# 5        17        13   19         2       1
# ..      ...       ...  ...       ...     ...
# 0        12        16   17         5       0
# 1        13        16   15         5       0
# 3        11        16   15         5       0
# 4         0        16   15         5       0
# 5        20        16   15         5       0
#
# [115 rows x 33 columns]

# %%
group = grouped_matches.get_group('Manchester City')
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W   4   0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W   5   0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W   5   1
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D   2   2
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   3   2
#
#            opponent  ...   pk  pkatt  season             team venue_code  \
# 1          West Ham  ...  1.0    1.0    2023  Manchester City          0
# 2       Bournemouth  ...  0.0    0.0    2023  Manchester City          1
# 3     Newcastle Utd  ...  0.0    0.0    2023  Manchester City          0
# 4    Crystal Palace  ...  0.0    0.0    2023  Manchester City          1
# 5   Nott'ham Forest  ...  0.0    0.0    2023  Manchester City          1
# ..              ...  ...  ...    ...     ...              ...        ...
# 52     Leeds United  ...  0.0    0.0    2022  Manchester City          0
# 54    Newcastle Utd  ...  0.0    0.0    2022  Manchester City          1
# 55           Wolves  ...  0.0    0.0    2022  Manchester City          0
# 56         West Ham  ...  0.0    1.0    2022  Manchester City          0
# 57      Aston Villa  ...  0.0    0.0    2022  Manchester City          1
#
#    opp_code team_code hour  day_code  target
# 1        21        13   16         6       1
# 2         2        13   15         5       1
# 3        15        13   16         6       0
# 4         7        13   15         5       1
# 5        17        13   19         2       1
# ..      ...       ...  ...       ...     ...
# 52       10        13   17         5       1
# 54       15        13   16         6       1
# 55       22        13   20         2       1
# 56       21        13   14         6       0
# 57        1        13   16         6       1
#
# [76 rows x 33 columns]

# %% [markdown]
# #### ADDING ROLLING AVERAGE (TAKING PAST 3 WEEKS DATA INTO CONSIDERATION)

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W   1   0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D   2   2
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W   2   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4   Leicester City  ...         5       1    3.333333    0.333333  19.666667
# 6      Southampton  ...         5       0    3.666667    0.000000  22.000000
# 8          Chelsea  ...         5       1    2.000000    0.000000  22.000000
# 10       Liverpool  ...         6       0    0.666667    0.000000  18.666667
# 11         Burnley  ...         5       1    1.000000    0.666667  14.333333
# ..             ...  ...       ...     ...         ...         ...        ...
# 52    Leeds United  ...         5       1    3.000000    0.666667  13.666667
# 54         Everton  ...         6       1    2.333333    0.666667  14.666667
# 56         Chelsea  ...         6       1    2.666667    0.333333  14.000000
# 57        Brighton  ...         2       0    2.000000    0.333333  13.666667
# 58       Brentford  ...         6       0    1.666667    0.333333  12.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     6.000000    16.866667   0.666667    0.000000       0.000000
# 6     7.333333    15.866667   0.333333    0.000000       0.000000
# 8     6.333333    15.166667   0.333333    0.000000       0.000000
# 10    4.000000    15.933333   0.333333    0.000000       0.000000
# 11    2.333333    16.833333   0.666667    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 52    8.000000    15.433333   0.000000    0.333333       0.333333
# 54    7.000000    16.366667   0.666667    0.333333       0.666667
# 56    5.666667    18.100000   1.333333    0.000000       0.333333
# 57    4.000000    18.933333   1.333333    0.000000       0.333333
# 58    3.333333    17.333333   0.666667    0.000000       0.000000
#
# [73 rows x 41 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
#                             day venue result  gf  ga        opponent  ...  \
# team                                                                  ...
# Arsenal                 4   Sat  Home      W   1   0    Norwich City  ...
#                         5   Sat  Away      W   1   0         Burnley  ...
#                         7   Sun  Home      W   3   1       Tottenham  ...
#                         8   Sat  Away      D   0   0        Brighton  ...
#                         9   Mon  Home      D   2   2  Crystal Palace  ...
# ...                         ...   ...    ...  ..  ..             ...  ...
# Wolverhampton Wanderers 39  Sat  Away      L   0   6        Brighton  ...
#                         40  Sat  Home      W   1   0     Aston Villa  ...
#                         41  Sat  Away      L   0   2  Manchester Utd  ...
#                         42  Sat  Home      D   1   1         Everton  ...
#                         43  Sun  Away      L   0   5         Arsenal  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5       1    0.000000    3.000000
#                         5          5       1    0.333333    2.333333
#                         7          6       1    0.666667    1.666667
#                         8          5       0    1.666667    0.333333
#                         9          0       0    1.333333    0.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 39         5       0    1.666667    0.666667
#                         40         5       1    1.000000    2.666667
#                         41         5       0    1.000000    2.000000
#                         42         5       0    0.333333    2.666667
#                         43         6       0    0.666667    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.833333   0.333333
#                         5   12.333333    3.000000    14.133333   0.333333
#                         7   14.666667    3.000000    14.800000   0.666667
#                         8   18.333333    5.333333    18.433333   0.666667
#                         9   11.000000    4.000000    19.833333   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 39  11.666667    4.666667    18.700000   0.666667
#                         40  11.333333    2.333333    18.800000   0.666667
#                         41   8.000000    2.000000    17.766667   0.000000
#                         42   7.000000    1.333333    15.600000   0.000000
#                         43   8.000000    2.333333    15.333333   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.000000       0.000000
#                         5     0.000000       0.000000
#                         7     0.000000       0.000000
#                         8     0.000000       0.000000
#                         9     0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 39    0.333333       0.333333
#                         40    0.333333       0.333333
#                         41    0.333333       0.333333
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#
# [1451 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1446 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0
# 1447 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1
# 1448 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0
# 1449 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1
# 1450 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0
#
#       ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0      0    Norwich City  ...         5       1    0.000000    3.000000
# 1      0         Burnley  ...         5       1    0.333333    2.333333
# 2      1       Tottenham  ...         6       1    0.666667    1.666667
# 3      0        Brighton  ...         5       0    1.666667    0.333333
# 4      2  Crystal Palace  ...         0       0    1.333333    0.333333
# ...   ..             ...  ...       ...     ...         ...         ...
# 1446   6        Brighton  ...         5       0    1.666667    0.666667
# 1447   0     Aston Villa  ...         5       1    1.000000    2.666667
# 1448   2  Manchester Utd  ...         5       0    1.000000    2.000000
# 1449   1         Everton  ...         5       0    0.333333    2.666667
# 1450   5         Arsenal  ...         6       0    0.666667    1.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 1     12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 2     14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 3     18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 4     11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ...         ...         ...          ...        ...         ...            ...
# 1446  11.666667    4.666667    18.700000   0.666667    0.333333       0.333333
# 1447  11.333333    2.333333    18.800000   0.666667    0.333333       0.333333
# 1448   8.000000    2.000000    17.766667   0.000000    0.333333       0.333333
# 1449   7.000000    1.333333    15.600000   0.000000    0.000000       0.000000
# 1450   8.000000    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [1451 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] >= '2023-01-01']
    rf.fit(train[predictors], train['target'])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame({'Actual':test['target'], 'Prediction':preds})
    acc =accuracy_score(test['target'], preds)
    precision = precision_score(combined['Actual'], combined['Prediction'])
    return combined, acc, precision

# %%
combined, acc2, precision2 = make_predictions(matches_rolling, predictors+new_cols)

# %%
acc, acc2
# Out:
# (0.5949074074074074, 0.6342592592592593)

# %%
precision, precision2
# Out:
# (0.4608695652173913, 0.5384615384615384)

# %% [markdown]
# ### OBSERVATION: USING ROLLING AVERAGES AND NEW PREDICTORS IMPROVED BOTH ACCURACY AND PRECISION.

# %%
combined = combined.merge(matches_rolling[['date','team', 'opponent', 'result', 'venue']], right_index=True, left_index=True)
combined
# Out:
#       Actual  Prediction       date                     team        opponent  \
# 51         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 52         1           0 2023-01-15                  Arsenal       Tottenham
# 53         1           1 2023-01-22                  Arsenal  Manchester Utd
# 54         0           1 2023-02-04                  Arsenal         Everton
# 55         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 1446       0           0 2023-04-29  Wolverhampton Wanderers        Brighton
# 1447       1           0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 1448       0           0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 1449       0           0 2023-05-20  Wolverhampton Wanderers         Everton
# 1450       0           0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result venue
# 51        D  Home
# 52        W  Away
# 53        W  Home
# 54        L  Away
# 55        D  Home
# ...     ...   ...
# 1446      L  Away
# 1447      W  Home
# 1448      L  Away
# 1449      D  Home
# 1450      L  Away
#
# [432 rows x 7 columns]

# %% [markdown]
# #### IMPROVING DATA CONSISTENCY FOR ANALYSIS

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
team_map = {}
for i, team in enumerate(sorted(combined['team'].unique())):
    team_map[team] = sorted(combined['opponent'].unique())[i]
mapping = MissingDict(**team_map)

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       Actual  Prediction       date                     team        opponent  \
# 51         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 52         1           0 2023-01-15                  Arsenal       Tottenham
# 53         1           1 2023-01-22                  Arsenal  Manchester Utd
# 54         0           1 2023-02-04                  Arsenal         Everton
# 55         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 1446       0           0 2023-04-29  Wolverhampton Wanderers        Brighton
# 1447       1           0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 1448       0           0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 1449       0           0 2023-05-20  Wolverhampton Wanderers         Everton
# 1450       0           0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result venue new_team
# 51        D  Home  Arsenal
# 52        W  Away  Arsenal
# 53        W  Home  Arsenal
# 54        L  Away  Arsenal
# 55        D  Home  Arsenal
# ...     ...   ...      ...
# 1446      L  Away   Wolves
# 1447      W  Home   Wolves
# 1448      L  Away   Wolves
# 1449      D  Home   Wolves
# 1450      L  Away   Wolves
#
# [432 rows x 8 columns]

# %%
merged = combined.merge(combined, left_on=['date', 'team'], right_on=['date', 'opponent'])
merged
# Out:
#      Actual_x  Prediction_x       date       team_x       opponent_x result_x  \
# 0           0             1 2023-01-03      Arsenal    Newcastle Utd        D
# 1           1             0 2023-01-15      Arsenal        Tottenham        W
# 2           1             1 2023-01-22      Arsenal   Manchester Utd        W
# 3           0             1 2023-02-04      Arsenal          Everton        L
# 4           0             1 2023-02-11      Arsenal        Brentford        D
# ..        ...           ...        ...          ...              ...      ...
# 276         0             0 2023-04-30  Southampton    Newcastle Utd        L
# 277         0             0 2023-05-08  Southampton  Nott'ham Forest        L
# 278         0             0 2023-05-13  Southampton           Fulham        L
# 279         0             0 2023-05-21  Southampton         Brighton        L
# 280         0             0 2023-05-28  Southampton        Liverpool        D
#
#     venue_x   new_team_x  Actual_y  Prediction_y                    team_y  \
# 0      Home      Arsenal         0             0          Newcastle United
# 1      Away      Arsenal         0             0         Tottenham Hotspur
# 2      Home      Arsenal         0             1         Manchester United
# 3      Away      Arsenal         1             0                   Everton
# 4      Home      Arsenal         0             0                 Brentford
# ..      ...          ...       ...           ...                       ...
# 276    Away  Southampton         1             1          Newcastle United
# 277    Away  Southampton         1             0         Nottingham Forest
# 278    Home  Southampton         1             0                    Fulham
# 279    Away  Southampton         1             0  Brighton and Hove Albion
# 280    Home  Southampton         0             1                 Liverpool
#
#       opponent_y result_y venue_y       new_team_y
# 0        Arsenal        D    Away    Newcastle Utd
# 1        Arsenal        L    Home        Tottenham
# 2        Arsenal        L    Away   Manchester Utd
# 3        Arsenal        W    Home          Everton
# 4        Arsenal        D    Away        Brentford
# ..           ...      ...     ...              ...
# 276  Southampton        W    Home    Newcastle Utd
# 277  Southampton        W    Home  Nott'ham Forest
# 278  Southampton        W    Away           Fulham
# 279  Southampton        W    Home         Brighton
# 280  Southampton        D    Away        Liverpool
#
# [281 rows x 15 columns]

# %%
merged[(merged['Prediction_x'] == 1) & (merged['Prediction_y'] == 0)]['Actual_x'].value_counts()
# Out:
# Actual_x
# 1    32
# 0    24
# Name: count, dtype: int64
